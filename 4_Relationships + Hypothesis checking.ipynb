# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Importing data

df = pd.read_csv('data/eda_cleaned+improved.csv', delimiter=",")

df.columns
# Out:
# Index(['house_id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'date', 'price', 'transaction_id',
#        'price_cat_total', 'price_sqft', 'price_cat_sqft', 'neighborhood_name'],
#       dtype='object')

# %%
# pairplot with hue price


sns.pairplot(df[['price', 'sqft_living', 'floors', 'grade', 'condition']])
# to show
plt.show()
